# %%
import pandas as pd  
import peakbox_v5 as pbk
import dill

import warnings
warnings.filterwarnings('ignore')

# %%
#INPUTS:

# Decide simulation starting time:
sim_start = '2018-10-26 12:00:00'

#upload the dataframes containing the ensemble forecasts and the observations:
ens = pd.read_csv("https://raw.githubusercontent.com/agiord/peakbox/master/ens.csv", sep=",")
obs = pd.read_csv("https://raw.githubusercontent.com/agiord/peakbox/master/obs.csv", sep=",")

ens['date'] = pd.to_datetime(ens['date'])
obs['date'] = pd.to_datetime(obs['date'])

# %%
ens.head()
# Out:
#        rm00      rm01      rm02      rm03      rm04      rm05      rm06  \
# 0  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667
# 1  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667
# 2  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667
# 3  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667
# 4  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667  1.136667
#
#        rm07      rm08      rm09  ...      rm12      rm13      rm14      rm15  \
# 0  1.136667  1.136667  1.136667  ...  1.136667  1.136667  1.136667  1.136667
# 1  1.136667  1.136667  1.136667  ...  1.136667  1.136667  1.136667  1.136667
# 2  1.136667  1.136667  1.136667  ...  1.136667  1.136667  1.136667  1.136667
# 3  1.136667  1.136667  1.136667  ...  1.136667  1.136667  1.136667  1.136667
# 4  1.136667  1.136667  1.136667  ...  1.136667  1.136667  1.136667  1.136667
#
# ...

# %%
obs.head()
# Out:
#    year  month  day  hour  runoff                date
# 0  2018     10   26    13   2.268 2018-10-26 13:00:00
# 1  2018     10   26    14   2.268 2018-10-26 14:00:00
# 2  2018     10   26    15   2.269 2018-10-26 15:00:00
# 3  2018     10   26    16   2.268 2018-10-26 16:00:00
# 4  2018     10   26    17   2.267 2018-10-26 17:00:00

# %%
pbk.peak_box_multipeaks(ens, obs, sim_start)

# %%
#SOME MORE EXAMPLES:

# Decide simulation starting time:
sim_start2 = '2018-10-27 12:00:00'

#upload the dataframes containing the ensemble forecasts and the observations:
ens2 = dill.load( open( "./ens2.csv", "rb" ) )
obs2 = dill.load( open( "./obs2.csv", "rb" ) )

ens2['date'] = pd.to_datetime(ens2['date'])
obs2['date'] = pd.to_datetime(obs2['date'])


# Decide simulation starting time:
sim_start3 = '2018-10-28 12:00:00'

#upload the dataframes containing the ensemble forecasts and the observations:
ens3 = dill.load( open( "./ens3.csv", "rb" ) )
obs3 = dill.load( open( "./obs3.csv", "rb" ) )

ens3['date'] = pd.to_datetime(ens3['date'])
obs3['date'] = pd.to_datetime(obs3['date'])


# Decide simulation starting time:
sim_start4 = '2018-11-09 12:00:00'

#upload the dataframes containing the ensemble forecasts and the observations:
ens4 = dill.load( open( "./ens4.csv", "rb" ) )
obs4 = dill.load( open( "./obs4.csv", "rb" ) )

ens4['date'] = pd.to_datetime(ens4['date'])
obs4['date'] = pd.to_datetime(obs4['date'])

# %%
pbk.peak_box_multipeaks(ens2, obs2, sim_start2)

# %%
pbk.peak_box_multipeaks(ens3, obs3, sim_start3)

# %%
pbk.peak_box_multipeaks(ens4, obs4, sim_start4)
